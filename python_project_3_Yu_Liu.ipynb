# %%
import pandas as pd
import numpy as np
import requests


#import environment

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/qgea-i56i.csv')
#import dataframe

# %%
df
#check dataframe
# Out:
#     cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm             cmplnt_to_dt  \
# 0     10600119  2002-01-01T00:00:00.000     11:00:00  2006-02-25T00:00:00.000
# 1     11052575  2005-04-22T00:00:00.000     02:00:00                      NaN
# 2     10832306  2005-07-11T00:00:00.000     20:00:00  2006-03-29T00:00:00.000
# 3     10107192  2005-10-19T00:00:00.000     20:30:00                      NaN
# 4     23893731  2005-12-04T00:00:00.000     09:00:00  2006-08-09T00:00:00.000
# ..         ...                      ...          ...                      ...
# 995   28601067  2002-10-01T00:00:00.000     00:00:00  2007-04-20T00:00:00.000
# 996   64716118  1995-09-01T00:00:00.000     00:00:00  2000-03-01T00:00:00.000
# 997  140224707  2002-05-05T00:00:00.000     03:30:00  2009-05-21T00:00:00.000
# 998   10307299  2005-06-12T00:00:00.000     10:00:00  2005-06-12T00:00:00.000
# 999   16582938  2005-05-25T00:00:00.000     23:00:00  2006-05-25T00:00:00.000
#
#     cmplnt_to_tm  addr_pct_cd                   rpt_dt  ky_cd  \
# 0       11:00:00          NaN  2006-03-06T00:00:00.000    104
# 1         (null)          NaN  2006-04-22T00:00:00.000    110
# 2       12:00:00          NaN  2006-03-29T00:00:00.000    353
# 3         (null)          NaN  2006-01-13T00:00:00.000    126
# 4       17:00:00          NaN  2006-08-09T00:00:00.000    109
# ..           ...          ...                      ...    ...
# 995     20:00:00         77.0  2007-04-20T00:00:00.000    109
# 996     00:00:00         83.0  2009-08-12T00:00:00.000    116
# 997     11:15:00          5.0  2014-12-17T00:00:00.000    112
# 998     12:00:00         67.0  2006-02-05T00:00:00.000    112
# 999     23:15:00        115.0  2006-05-26T00:00:00.000    126
#
#                           ofns_desc  pd_cd  ... susp_sex transit_district  \
# 0                              RAPE  157.0  ...        M              NaN
# 1    GRAND LARCENY OF MOTOR VEHICLE  441.0  ...   (null)              NaN
# 2     UNAUTHORIZED USE OF A VEHICLE  462.0  ...        M              NaN
# 3           MISCELLANEOUS PENAL LAW  461.0  ...        F              NaN
# 4                     GRAND LARCENY  405.0  ...   (null)              NaN
# ..                              ...    ...  ...      ...              ...
# 995                   GRAND LARCENY  438.0  ...   (null)              NaN
# 996                      SEX CRIMES  179.0  ...        M              NaN
# 997                     THEFT-FRAUD  739.0  ...   (null)              NaN
# 998                     THEFT-FRAUD  739.0  ...   (null)              NaN
# 999         MISCELLANEOUS PENAL LAW  198.0  ...   (null)              NaN
#
#       latitude  longitude                                lat_lon  \
# 0          NaN        NaN                                    NaN
# 1          NaN        NaN                                    NaN
# 2          NaN        NaN                                    NaN
# 3          NaN        NaN                                    NaN
# 4          NaN        NaN                                    NaN
# ..         ...        ...                                    ...
# 995  40.674496 -73.930571  (40.6744956865259, -73.9305713255961)
# 996  40.698474 -73.917769   (40.6984738177025, -73.917768981221)
# 997  40.716012 -73.997332  (40.7160120119955, -73.9973320301008)
# 998  40.648851 -73.951017   (40.6488507469884, -73.951016510623)
# 999  40.756568 -73.875932  (40.7565675846374, -73.8759315341335)
#
#                   patrol_boro station_name  vic_age_group        vic_race  \
# 0                      (null)       (null)          18-24           WHITE
# 1                      (null)       (null)          25-44           BLACK
# 2                      (null)       (null)          45-64           WHITE
# 3                      (null)       (null)          25-44           BLACK
# 4                      (null)       (null)          25-44           WHITE
# ..                        ...          ...            ...             ...
# 995   PATROL BORO BKLYN NORTH       (null)          25-44           BLACK
# 996   PATROL BORO BKLYN NORTH       (null)          18-24  WHITE HISPANIC
# 997     PATROL BORO MAN SOUTH       (null)          25-44           BLACK
# 998   PATROL BORO BKLYN SOUTH       (null)          25-44           BLACK
# 999  PATROL BORO QUEENS NORTH       (null)          25-44  WHITE HISPANIC
#
#     vic_sex
# 0         F
# 1         M
# 2         M
# 3         F
# 4         F
# ..      ...
# 995       M
# 996       F
# 997       M
# 998       F
# 999       F
#
# [1000 rows x 35 columns]

# %%
df.columns
#check all the column names
# Out:
# Index(['cmplnt_num', 'cmplnt_fr_dt', 'cmplnt_fr_tm', 'cmplnt_to_dt',
#        'cmplnt_to_tm', 'addr_pct_cd', 'rpt_dt', 'ky_cd', 'ofns_desc', 'pd_cd',
#        'pd_desc', 'crm_atpt_cptd_cd', 'law_cat_cd', 'boro_nm',
#        'loc_of_occur_desc', 'prem_typ_desc', 'juris_desc', 'jurisdiction_code',
#        'parks_nm', 'hadevelopt', 'housing_psa', 'x_coord_cd', 'y_coord_cd',
#        'susp_age_group', 'susp_race', 'susp_sex', 'transit_district',
#        'latitude', 'longitude', 'lat_lon', 'patrol_boro', 'station_name',
#        'vic_age_group', 'vic_race', 'vic_sex'],
#       dtype='object')

# %%
dff = pd.read_csv('https://raw.githubusercontent.com/AlbertUoU/data/main/1.csv')
#import all the explanation of all the columns names

# %%
dff
#check
# Out:
#           Column Name                                        Description  \
# 0          CMPLNT_NUM  Randomly generated persistent ID for each comp...
# 1        CMPLNT_FR_DT  Exact date of occurrence for the reported even...
# 2        CMPLNT_FR_TM  Exact time of occurrence for the reported even...
# 3        CMPLNT_TO_DT  Ending date of occurrence for the reported eve...
# 4        CMPLNT_TO_TM  Ending time of occurrence for the reported eve...
# 5         ADDR_PCT_CD        The precinct in which the incident occurred
# 6              RPT_DT                  Date event was reported to police
# 7               KY_CD            Three digit offense classification code
# 8           OFNS_DESC  Description of offense corresponding with key ...
# 9               PD_CD  Three digit internal classification code (more...
# 10            PD_DESC  Description of internal classification corresp...
# 11   CRM_ATPT_CPTD_CD  Indicator of whether crime was successfully co...
# 12         LAW_CAT_CD   Level of offense: felony, misdemeanor, violation
# 13            BORO_NM  The name of the borough in which the incident ...
# 14  LOC_OF_OCCUR_DESC  Specific location of occurrence in or around t...
# 15      PREM_TYP_DESC  Specific description of premises; grocery stor...
# 16         JURIS_DESC               Description of the jurisdiction code
# 17  JURISDICTION_CODE  Jurisdiction responsible for incident. Either ...
# 18           PARKS_NM  Name of NYC park, playground or greenspace of ...
# 19         HADEVELOPT  Name of NYCHA housing development of occurrenc...
# 20        HOUSING_PSA                             Development Level Code
# 21         X_COORD_CD  X-coordinate for New York State Plane Coordina...
# 22         Y_COORD_CD  Y-coordinate for New York State Plane Coordina...
# 23     SUSP_AGE_GROUP                                Suspect?s Age Group
# 24          SUSP_RACE                         Suspect?s Race Description
# 25           SUSP_SEX                          Suspect?s Sex Description
# 26   TRANSIT_DISTRICT    Transit district in which the offense occurred.
# 27           Latitude  Midblock Latitude coordinate for Global Coordi...
# 28          Longitude  Midblock Longitude coordinate for Global Coord...
# 29            Lat_Lon  Geospatial Location Point (latitude and Longit...
# 30        PATROL_BORO  The name of the patrol borough in which the in...
# 31       STATION_NAME                               Transit station name
# 32      VIC_AGE_GROUP                                 Victim?s Age Group
# 33           VIC_RACE                          Victim?s Race Description
# 34            VIC_SEX                           Victim?s Sex Description
#
#            Type  Unnamed: 3
# 0    Plain Text         NaN
# 1   Date & Time         NaN
# 2    Plain Text         NaN
# 3   Date & Time         NaN
# 4    Plain Text         NaN
# 5        Number         NaN
# 6   Date & Time         NaN
# 7        Number         NaN
# 8    Plain Text         NaN
# 9        Number         NaN
# 10   Plain Text         NaN
# 11   Plain Text         NaN
# 12   Plain Text         NaN
# 13   Plain Text         NaN
# 14   Plain Text         NaN
# 15   Plain Text         NaN
# 16   Plain Text         NaN
# 17       Number         NaN
# 18   Plain Text         NaN
# 19   Plain Text         NaN
# 20   Plain Text         NaN
# 21       Number         NaN
# 22       Number         NaN
# 23   Plain Text         NaN
# 24   Plain Text         NaN
# 25   Plain Text         NaN
# 26       Number         NaN
# 27       Number         NaN
# 28       Number         NaN
# 29     Location         NaN
# 30   Plain Text         NaN
# 31   Plain Text         NaN
# 32   Plain Text         NaN
# 33   Plain Text         NaN
# 34   Plain Text         NaN

# %%
new_column_names = dff.iloc[:, 1].tolist()


df.columns = new_column_names

# %%
df
# Out:
#     Randomly generated persistent ID for each complaint  \
# 0                                             10600119
# 1                                             11052575
# 2                                             10832306
# 3                                             10107192
# 4                                             23893731
# ..                                                 ...
# 995                                           28601067
# 996                                           64716118
# 997                                          140224707
# 998                                           10307299
# 999                                           16582938
#
#     Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)  \
# 0                              2002-01-01T00:00:00.000
# 1                              2005-04-22T00:00:00.000
# 2                              2005-07-11T00:00:00.000
# 3                              2005-10-19T00:00:00.000
# 4                              2005-12-04T00:00:00.000
# ..                                                 ...
# 995                            2002-10-01T00:00:00.000
# 996                            1995-09-01T00:00:00.000
# 997                            2002-05-05T00:00:00.000
# 998                            2005-06-12T00:00:00.000
# 999                            2005-05-25T00:00:00.000
#
#     Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)  \
# 0                                             11:00:00
# 1                                             02:00:00
# 2                                             20:00:00
# 3                                             20:30:00
# 4                                             09:00:00
# ..                                                 ...
# 995                                           00:00:00
# 996                                           00:00:00
# 997                                           03:30:00
# 998                                           10:00:00
# 999                                           23:00:00
#
#     Ending date of occurrence for the reported event, if exact time of occurrence is unknown  \
# 0                              2006-02-25T00:00:00.000
# 1                                                  NaN
# 2                              2006-03-29T00:00:00.000
# 3                                                  NaN
# 4                              2006-08-09T00:00:00.000
# ..                                                 ...
# 995                            2007-04-20T00:00:00.000
# 996                            2000-03-01T00:00:00.000
# 997                            2009-05-21T00:00:00.000
# 998                            2005-06-12T00:00:00.000
# 999                            2006-05-25T00:00:00.000
#
#     Ending time of occurrence for the reported event, if exact time of occurrence is unknown  \
# 0                                             11:00:00
# 1                                               (null)
# 2                                             12:00:00
# 3                                               (null)
# 4                                             17:00:00
# ..                                                 ...
# 995                                           20:00:00
# 996                                           00:00:00
# 997                                           11:15:00
# 998                                           12:00:00
# 999                                           23:15:00
#
#      The precinct in which the incident occurred  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 995                                         77.0
# 996                                         83.0
# 997                                          5.0
# 998                                         67.0
# 999                                        115.0
#
#     Date event was reported to police  \
# 0             2006-03-06T00:00:00.000
# 1             2006-04-22T00:00:00.000
# 2             2006-03-29T00:00:00.000
# 3             2006-01-13T00:00:00.000
# 4             2006-08-09T00:00:00.000
# ..                                ...
# 995           2007-04-20T00:00:00.000
# 996           2009-08-12T00:00:00.000
# 997           2014-12-17T00:00:00.000
# 998           2006-02-05T00:00:00.000
# 999           2006-05-26T00:00:00.000
#
#      Three digit offense classification code  \
# 0                                        104
# 1                                        110
# 2                                        353
# 3                                        126
# 4                                        109
# ..                                       ...
# 995                                      109
# 996                                      116
# 997                                      112
# 998                                      112
# 999                                      126
#
#     Description of offense corresponding with key code  \
# 0                                                 RAPE
# 1                       GRAND LARCENY OF MOTOR VEHICLE
# 2                        UNAUTHORIZED USE OF A VEHICLE
# 3                              MISCELLANEOUS PENAL LAW
# 4                                        GRAND LARCENY
# ..                                                 ...
# 995                                      GRAND LARCENY
# 996                                         SEX CRIMES
# 997                                        THEFT-FRAUD
# 998                                        THEFT-FRAUD
# 999                            MISCELLANEOUS PENAL LAW
#
#      Three digit internal classification code (more granular than Key Code)  \
# 0                                                157.0
# 1                                                441.0
# 2                                                462.0
# 3                                                461.0
# 4                                                405.0
# ..                                                 ...
# 995                                              438.0
# 996                                              179.0
# 997                                              739.0
# 998                                              739.0
# 999                                              198.0
#
#      ... Suspect?s Sex Description  \
# 0    ...                         M
# 1    ...                    (null)
# 2    ...                         M
# 3    ...                         F
# 4    ...                    (null)
# ..   ...                       ...
# 995  ...                    (null)
# 996  ...                         M
# 997  ...                    (null)
# 998  ...                    (null)
# 999  ...                    (null)
#
#     Transit district in which the offense occurred.  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 995                                             NaN
# 996                                             NaN
# 997                                             NaN
# 998                                             NaN
# 999                                             NaN
#
#     Midblock Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                          40.674496
# 996                                          40.698474
# 997                                          40.716012
# 998                                          40.648851
# 999                                          40.756568
#
#     Midblock Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                         -73.930571
# 996                                         -73.917769
# 997                                         -73.997332
# 998                                         -73.951017
# 999                                         -73.875932
#
#     Geospatial Location Point (latitude and Longitude combined)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995              (40.6744956865259, -73.9305713255961)
# 996               (40.6984738177025, -73.917768981221)
# 997              (40.7160120119955, -73.9973320301008)
# 998               (40.6488507469884, -73.951016510623)
# 999              (40.7565675846374, -73.8759315341335)
#
#     The name of the patrol borough in which the incident occurred  \
# 0                                               (null)
# 1                                               (null)
# 2                                               (null)
# 3                                               (null)
# 4                                               (null)
# ..                                                 ...
# 995                            PATROL BORO BKLYN NORTH
# 996                            PATROL BORO BKLYN NORTH
# 997                              PATROL BORO MAN SOUTH
# 998                            PATROL BORO BKLYN SOUTH
# 999                           PATROL BORO QUEENS NORTH
#
#     Transit station name  Victim?s Age Group Victim?s Race Description  \
# 0                 (null)               18-24                     WHITE
# 1                 (null)               25-44                     BLACK
# 2                 (null)               45-64                     WHITE
# 3                 (null)               25-44                     BLACK
# 4                 (null)               25-44                     WHITE
# ..                   ...                 ...                       ...
# 995               (null)               25-44                     BLACK
# 996               (null)               18-24            WHITE HISPANIC
# 997               (null)               25-44                     BLACK
# 998               (null)               25-44                     BLACK
# 999               (null)               25-44            WHITE HISPANIC
#
#     Victim?s Sex Description
# 0                          F
# 1                          M
# 2                          M
# 3                          F
# 4                          F
# ..                       ...
# 995                        M
# 996                        F
# 997                        M
# 998                        F
# 999                        F
#
# [1000 rows x 35 columns]

# %%
dff['Description'].unique()
#check
# Out:
# array(['Randomly generated persistent ID for each complaint',
#        'Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)',
#        'Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)',
#        'Ending date of occurrence for the reported event, if exact time of occurrence is unknown',
#        'Ending time of occurrence for the reported event, if exact time of occurrence is unknown',
#        'The precinct in which the incident occurred',
#        'Date event was reported to police',
#        'Three digit offense classification code',
#        'Description of offense corresponding with key code',
#        'Three digit internal classification code (more granular than Key Code)',
#        'Description of internal classification corresponding with PD code (more granular than Offense Description)',
#        'Indicator of whether crime was successfully completed or attempted, but failed or was interrupted prematurely',
#        'Level of offense: felony, misdemeanor, violation',
#        'The name of the borough in which the incident occurred',
#        'Specific location of occurrence in or around the premises; inside, opposite of, front of, rear of',
#        'Specific description of premises; grocery store, residence, street, etc.',
#        'Description of the jurisdiction code',
#        'Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.',
#        'Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)',
#        'Name of NYCHA housing development of occurrence, if applicable',
#        'Development Level Code',
#        'X-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)',
#        'Y-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)',
#        'Suspect?s Age Group', 'Suspect?s Race Description',
#        'Suspect?s Sex Description',
#        'Transit district in which the offense occurred.',
#        'Midblock Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)',
#        'Midblock Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)',
#        'Geospatial Location Point (latitude and Longitude combined)',
#        'The name of the patrol borough in which the incident occurred',
#        'Transit station name', 'Victim?s Age Group',
#        'Victim?s Race Description', 'Victim?s Sex Description'],
#       dtype=object)

# %%
dff['Column Name'].unique()
dff['Column Name'].count()
# Out:
# 35

# %%
df.shape
# Out:
# (1000, 35)

# %%
column_ranges = [(0, 9), (12, 18), (24, 26), (30, 32)]

subset_dfs = []
for start, end in column_ranges:
    subset_dfs.append(df.iloc[:, start:end+1])

df1 = pd.concat(subset_dfs, axis=1)

df1
# Out:
#     Randomly generated persistent ID for each complaint  \
# 0                                             10600119
# 1                                             11052575
# 2                                             10832306
# 3                                             10107192
# 4                                             23893731
# ..                                                 ...
# 995                                           28601067
# 996                                           64716118
# 997                                          140224707
# 998                                           10307299
# 999                                           16582938
#
#     Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)  \
# 0                              2002-01-01T00:00:00.000
# 1                              2005-04-22T00:00:00.000
# 2                              2005-07-11T00:00:00.000
# 3                              2005-10-19T00:00:00.000
# 4                              2005-12-04T00:00:00.000
# ..                                                 ...
# 995                            2002-10-01T00:00:00.000
# 996                            1995-09-01T00:00:00.000
# 997                            2002-05-05T00:00:00.000
# 998                            2005-06-12T00:00:00.000
# 999                            2005-05-25T00:00:00.000
#
#     Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)  \
# 0                                             11:00:00
# 1                                             02:00:00
# 2                                             20:00:00
# 3                                             20:30:00
# 4                                             09:00:00
# ..                                                 ...
# 995                                           00:00:00
# 996                                           00:00:00
# 997                                           03:30:00
# 998                                           10:00:00
# 999                                           23:00:00
#
#     Ending date of occurrence for the reported event, if exact time of occurrence is unknown  \
# 0                              2006-02-25T00:00:00.000
# 1                                                  NaN
# 2                              2006-03-29T00:00:00.000
# 3                                                  NaN
# 4                              2006-08-09T00:00:00.000
# ..                                                 ...
# 995                            2007-04-20T00:00:00.000
# 996                            2000-03-01T00:00:00.000
# 997                            2009-05-21T00:00:00.000
# 998                            2005-06-12T00:00:00.000
# 999                            2006-05-25T00:00:00.000
#
#     Ending time of occurrence for the reported event, if exact time of occurrence is unknown  \
# 0                                             11:00:00
# 1                                               (null)
# 2                                             12:00:00
# 3                                               (null)
# 4                                             17:00:00
# ..                                                 ...
# 995                                           20:00:00
# 996                                           00:00:00
# 997                                           11:15:00
# 998                                           12:00:00
# 999                                           23:15:00
#
#      The precinct in which the incident occurred  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 995                                         77.0
# 996                                         83.0
# 997                                          5.0
# 998                                         67.0
# 999                                        115.0
#
#     Date event was reported to police  \
# 0             2006-03-06T00:00:00.000
# 1             2006-04-22T00:00:00.000
# 2             2006-03-29T00:00:00.000
# 3             2006-01-13T00:00:00.000
# 4             2006-08-09T00:00:00.000
# ..                                ...
# 995           2007-04-20T00:00:00.000
# 996           2009-08-12T00:00:00.000
# 997           2014-12-17T00:00:00.000
# 998           2006-02-05T00:00:00.000
# 999           2006-05-26T00:00:00.000
#
#      Three digit offense classification code  \
# 0                                        104
# 1                                        110
# 2                                        353
# 3                                        126
# 4                                        109
# ..                                       ...
# 995                                      109
# 996                                      116
# 997                                      112
# 998                                      112
# 999                                      126
#
#     Description of offense corresponding with key code  \
# 0                                                 RAPE
# 1                       GRAND LARCENY OF MOTOR VEHICLE
# 2                        UNAUTHORIZED USE OF A VEHICLE
# 3                              MISCELLANEOUS PENAL LAW
# 4                                        GRAND LARCENY
# ..                                                 ...
# 995                                      GRAND LARCENY
# 996                                         SEX CRIMES
# 997                                        THEFT-FRAUD
# 998                                        THEFT-FRAUD
# 999                            MISCELLANEOUS PENAL LAW
#
#      Three digit internal classification code (more granular than Key Code)  \
# 0                                                157.0
# 1                                                441.0
# 2                                                462.0
# 3                                                461.0
# 4                                                405.0
# ..                                                 ...
# 995                                              438.0
# 996                                              179.0
# 997                                              739.0
# 998                                              739.0
# 999                                              198.0
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 995  ...
# 996  ...
# 997  ...
# 998  ...
# 999  ...
#
#     Specific description of premises; grocery store, residence, street, etc.  \
# 0                                               (null)
# 1                                               (null)
# 2                                               (null)
# 3                                               (null)
# 4                                               (null)
# ..                                                 ...
# 995                             RESIDENCE - APT. HOUSE
# 996                             RESIDENCE - APT. HOUSE
# 997                                    RESIDENCE-HOUSE
# 998                                    RESIDENCE-HOUSE
# 999                             RESIDENCE - APT. HOUSE
#
#     Description of the jurisdiction code  \
# 0                       N.Y. POLICE DEPT
# 1                       N.Y. POLICE DEPT
# 2                       N.Y. POLICE DEPT
# 3                       N.Y. POLICE DEPT
# 4                       N.Y. POLICE DEPT
# ..                                   ...
# 995                     N.Y. POLICE DEPT
# 996                     N.Y. POLICE DEPT
# 997                     N.Y. POLICE DEPT
# 998                     N.Y. POLICE DEPT
# 999                     N.Y. POLICE DEPT
#
#     Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 995                                                  0
# 996                                                  0
# 997                                                  0
# 998                                                  0
# 999                                                  0
#
#     Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)  \
# 0                                               (null)
# 1                                               (null)
# 2                                               (null)
# 3                                               (null)
# 4                                               (null)
# ..                                                 ...
# 995                                             (null)
# 996                                             (null)
# 997                                             (null)
# 998                                             (null)
# 999                                             (null)
#
#     Suspect?s Race Description  Suspect?s Sex Description  \
# 0                        WHITE                          M
# 1                       (null)                     (null)
# 2                        WHITE                          M
# 3                        BLACK                          F
# 4                       (null)                     (null)
# ..                         ...                        ...
# 995                     (null)                     (null)
# 996             WHITE HISPANIC                          M
# 997                     (null)                     (null)
# 998                     (null)                     (null)
# 999                     (null)                     (null)
#
#     Transit district in which the offense occurred.  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 995                                             NaN
# 996                                             NaN
# 997                                             NaN
# 998                                             NaN
# 999                                             NaN
#
#     The name of the patrol borough in which the incident occurred  \
# 0                                               (null)
# 1                                               (null)
# 2                                               (null)
# 3                                               (null)
# 4                                               (null)
# ..                                                 ...
# 995                            PATROL BORO BKLYN NORTH
# 996                            PATROL BORO BKLYN NORTH
# 997                              PATROL BORO MAN SOUTH
# 998                            PATROL BORO BKLYN SOUTH
# 999                           PATROL BORO QUEENS NORTH
#
#     Transit station name  Victim?s Age Group
# 0                 (null)               18-24
# 1                 (null)               25-44
# 2                 (null)               45-64
# 3                 (null)               25-44
# 4                 (null)               25-44
# ..                   ...                 ...
# 995               (null)               25-44
# 996               (null)               18-24
# 997               (null)               25-44
# 998               (null)               25-44
# 999               (null)               25-44
#
# [1000 rows x 23 columns]

# %%
df1
# Out:
#     Randomly generated persistent ID for each complaint  \
# 0                                             10600119
# 1                                             11052575
# 2                                             10832306
# 3                                             10107192
# 4                                             23893731
# ..                                                 ...
# 995                                           28601067
# 996                                           64716118
# 997                                          140224707
# 998                                           10307299
# 999                                           16582938
#
#     Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)  \
# 0                              2002-01-01T00:00:00.000
# 1                              2005-04-22T00:00:00.000
# 2                              2005-07-11T00:00:00.000
# 3                              2005-10-19T00:00:00.000
# 4                              2005-12-04T00:00:00.000
# ..                                                 ...
# 995                            2002-10-01T00:00:00.000
# 996                            1995-09-01T00:00:00.000
# 997                            2002-05-05T00:00:00.000
# 998                            2005-06-12T00:00:00.000
# 999                            2005-05-25T00:00:00.000
#
#     Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)  \
# 0                                             11:00:00
# 1                                             02:00:00
# 2                                             20:00:00
# 3                                             20:30:00
# 4                                             09:00:00
# ..                                                 ...
# 995                                           00:00:00
# 996                                           00:00:00
# 997                                           03:30:00
# 998                                           10:00:00
# 999                                           23:00:00
#
#     Ending date of occurrence for the reported event, if exact time of occurrence is unknown  \
# 0                              2006-02-25T00:00:00.000
# 1                                                  NaN
# 2                              2006-03-29T00:00:00.000
# 3                                                  NaN
# 4                              2006-08-09T00:00:00.000
# ..                                                 ...
# 995                            2007-04-20T00:00:00.000
# 996                            2000-03-01T00:00:00.000
# 997                            2009-05-21T00:00:00.000
# 998                            2005-06-12T00:00:00.000
# 999                            2006-05-25T00:00:00.000
#
#     Ending time of occurrence for the reported event, if exact time of occurrence is unknown  \
# 0                                             11:00:00
# 1                                               (null)
# 2                                             12:00:00
# 3                                               (null)
# 4                                             17:00:00
# ..                                                 ...
# 995                                           20:00:00
# 996                                           00:00:00
# 997                                           11:15:00
# 998                                           12:00:00
# 999                                           23:15:00
#
#      The precinct in which the incident occurred  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 995                                         77.0
# 996                                         83.0
# 997                                          5.0
# 998                                         67.0
# 999                                        115.0
#
#     Date event was reported to police  \
# 0             2006-03-06T00:00:00.000
# 1             2006-04-22T00:00:00.000
# 2             2006-03-29T00:00:00.000
# 3             2006-01-13T00:00:00.000
# 4             2006-08-09T00:00:00.000
# ..                                ...
# 995           2007-04-20T00:00:00.000
# 996           2009-08-12T00:00:00.000
# 997           2014-12-17T00:00:00.000
# 998           2006-02-05T00:00:00.000
# 999           2006-05-26T00:00:00.000
#
#      Three digit offense classification code  \
# 0                                        104
# 1                                        110
# 2                                        353
# 3                                        126
# 4                                        109
# ..                                       ...
# 995                                      109
# 996                                      116
# 997                                      112
# 998                                      112
# 999                                      126
#
#     Description of offense corresponding with key code  \
# 0                                                 RAPE
# 1                       GRAND LARCENY OF MOTOR VEHICLE
# 2                        UNAUTHORIZED USE OF A VEHICLE
# 3                              MISCELLANEOUS PENAL LAW
# 4                                        GRAND LARCENY
# ..                                                 ...
# 995                                      GRAND LARCENY
# 996                                         SEX CRIMES
# 997                                        THEFT-FRAUD
# 998                                        THEFT-FRAUD
# 999                            MISCELLANEOUS PENAL LAW
#
#      Three digit internal classification code (more granular than Key Code)  \
# 0                                                157.0
# 1                                                441.0
# 2                                                462.0
# 3                                                461.0
# 4                                                405.0
# ..                                                 ...
# 995                                              438.0
# 996                                              179.0
# 997                                              739.0
# 998                                              739.0
# 999                                              198.0
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 995  ...
# 996  ...
# 997  ...
# 998  ...
# 999  ...
#
#     Specific description of premises; grocery store, residence, street, etc.  \
# 0                                               (null)
# 1                                               (null)
# 2                                               (null)
# 3                                               (null)
# 4                                               (null)
# ..                                                 ...
# 995                             RESIDENCE - APT. HOUSE
# 996                             RESIDENCE - APT. HOUSE
# 997                                    RESIDENCE-HOUSE
# 998                                    RESIDENCE-HOUSE
# 999                             RESIDENCE - APT. HOUSE
#
#     Description of the jurisdiction code  \
# 0                       N.Y. POLICE DEPT
# 1                       N.Y. POLICE DEPT
# 2                       N.Y. POLICE DEPT
# 3                       N.Y. POLICE DEPT
# 4                       N.Y. POLICE DEPT
# ..                                   ...
# 995                     N.Y. POLICE DEPT
# 996                     N.Y. POLICE DEPT
# 997                     N.Y. POLICE DEPT
# 998                     N.Y. POLICE DEPT
# 999                     N.Y. POLICE DEPT
#
#     Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 995                                                  0
# 996                                                  0
# 997                                                  0
# 998                                                  0
# 999                                                  0
#
#     Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)  \
# 0                                               (null)
# 1                                               (null)
# 2                                               (null)
# 3                                               (null)
# 4                                               (null)
# ..                                                 ...
# 995                                             (null)
# 996                                             (null)
# 997                                             (null)
# 998                                             (null)
# 999                                             (null)
#
#     Suspect?s Race Description  Suspect?s Sex Description  \
# 0                        WHITE                          M
# 1                       (null)                     (null)
# 2                        WHITE                          M
# 3                        BLACK                          F
# 4                       (null)                     (null)
# ..                         ...                        ...
# 995                     (null)                     (null)
# 996             WHITE HISPANIC                          M
# 997                     (null)                     (null)
# 998                     (null)                     (null)
# 999                     (null)                     (null)
#
#     Transit district in which the offense occurred.  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 995                                             NaN
# 996                                             NaN
# 997                                             NaN
# 998                                             NaN
# 999                                             NaN
#
#     The name of the patrol borough in which the incident occurred  \
# 0                                               (null)
# 1                                               (null)
# 2                                               (null)
# 3                                               (null)
# 4                                               (null)
# ..                                                 ...
# 995                            PATROL BORO BKLYN NORTH
# 996                            PATROL BORO BKLYN NORTH
# 997                              PATROL BORO MAN SOUTH
# 998                            PATROL BORO BKLYN SOUTH
# 999                           PATROL BORO QUEENS NORTH
#
#     Transit station name  Victim?s Age Group
# 0                 (null)               18-24
# 1                 (null)               25-44
# 2                 (null)               45-64
# 3                 (null)               25-44
# 4                 (null)               25-44
# ..                   ...                 ...
# 995               (null)               25-44
# 996               (null)               18-24
# 997               (null)               25-44
# 998               (null)               25-44
# 999               (null)               25-44
#
# [1000 rows x 23 columns]

# %%
for column in df.columns:
    value_counts = df[column].value_counts()
    most_common = value_counts.idxmax()
    most_common_count = value_counts.max()
    print(f"Most common value in '{column}': {most_common} (Count: {most_common_count})")

    # most showing up data in each column

    #common value in 'Suspect?s Age Group': (null) (Count: 740)
    #Most common value in 'Suspect?s Race Description': (null) (Count: 531)
    #Most common value in 'Suspect?s Sex Description': (null) (Count: 592)
    #I wish everyone can be safe because this mean police fail to get the criminal character for the most of the time, so it mean the crime would happen fast or on purpose with face covered
# Out:
# Most common value in 'Randomly generated persistent ID for each complaint': 10600119 (Count: 1)
# Most common value in 'Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)': 2005-01-01T00:00:00.000 (Count: 31)
# Most common value in 'Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)': 00:01:00 (Count: 190)
# Most common value in 'Ending date of occurrence for the reported event, if exact time of occurrence is unknown': 2005-12-31T00:00:00.000 (Count: 9)
# Most common value in 'Ending time of occurrence for the reported event, if exact time of occurrence is unknown': (null) (Count: 286)
# Most common value in 'The precinct in which the incident occurred': 47.0 (Count: 36)
# Most common value in 'Date event was reported to police': 2006-03-29T00:00:00.000 (Count: 8)
# Most common value in 'Three digit offense classification code': 109 (Count: 221)
# Most common value in 'Description of offense corresponding with key code': GRAND LARCENY (Count: 221)
# Most common value in 'Three digit internal classification code (more granular than Key Code)': 739.0 (Count: 157)
# Most common value in 'Description of internal classification corresponding with PD code (more granular than Offense Description)': FRAUD,UNCLASSIFIED-FELONY (Count: 157)
# Most common value in 'Indicator of whether crime was successfully completed or attempted, but failed or was interrupted prematurely': COMPLETED (Count: 977)
# Most common value in 'Level of offense: felony, misdemeanor, violation': FELONY (Count: 617)
# Most common value in 'The name of the borough in which the incident occurred': BROOKLYN (Count: 318)
# Most common value in 'Specific location of occurrence in or around the premises; inside, opposite of, front of, rear of': INSIDE (Count: 769)
# Most common value in 'Specific description of premises; grocery store, residence, street, etc.': RESIDENCE - APT. HOUSE (Count: 382)
# Most common value in 'Description of the jurisdiction code': N.Y. POLICE DEPT (Count: 901)
# Most common value in 'Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.': 0 (Count: 901)
# Most common value in 'Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)': (null) (Count: 1000)
# Most common value in 'Name of NYCHA housing development of occurrence, if applicable': (null) (Count: 994)
# Most common value in 'Development Level Code': (null) (Count: 920)
# Most common value in 'X-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)': 1026480.0 (Count: 36)
# Most common value in 'Y-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)': 262584.0 (Count: 36)
# Most common value in 'Suspect?s Age Group': (null) (Count: 740)
# Most common value in 'Suspect?s Race Description': (null) (Count: 531)
# Most common value in 'Suspect?s Sex Description': (null) (Count: 592)
# Most common value in 'Transit district in which the offense occurred.': 20.0 (Count: 1)
# Most common value in 'Midblock Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)': 40.8873136344706 (Count: 36)
# Most common value in 'Midblock Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)': -73.8472717577564 (Count: 36)
# Most common value in 'Geospatial Location Point (latitude and Longitude combined)': (40.8873136344706, -73.8472717577564) (Count: 36)
# Most common value in 'The name of the patrol borough in which the incident occurred': PATROL BORO BRONX (Count: 241)
# Most common value in 'Transit station name': (null) (Count: 998)
# Most common value in 'Victim?s Age Group': 25-44 (Count: 366)
# Most common value in 'Victim?s Race Description': BLACK (Count: 316)
# Most common value in 'Victim?s Sex Description': F (Count: 549)

# %%
for column in df.columns:
    non_null_values = df[column].dropna()  # Drop null values from the column
    value_counts = non_null_values.value_counts()

    if not value_counts.empty:
        most_common = value_counts.idxmax()
        most_common_count = value_counts.max()
        print(f"Most common value in '{column}': {most_common} (Count: {most_common_count})")
    else:
        print(f"No non-null values in '{column}'")
# Out:
# Most common value in 'Randomly generated persistent ID for each complaint': 10600119 (Count: 1)
# Most common value in 'Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)': 2005-01-01T00:00:00.000 (Count: 31)
# Most common value in 'Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)': 00:01:00 (Count: 190)
# Most common value in 'Ending date of occurrence for the reported event, if exact time of occurrence is unknown': 2005-12-31T00:00:00.000 (Count: 9)
# Most common value in 'Ending time of occurrence for the reported event, if exact time of occurrence is unknown': (null) (Count: 286)
# Most common value in 'The precinct in which the incident occurred': 47.0 (Count: 36)
# Most common value in 'Date event was reported to police': 2006-03-29T00:00:00.000 (Count: 8)
# Most common value in 'Three digit offense classification code': 109 (Count: 221)
# Most common value in 'Description of offense corresponding with key code': GRAND LARCENY (Count: 221)
# Most common value in 'Three digit internal classification code (more granular than Key Code)': 739.0 (Count: 157)
# Most common value in 'Description of internal classification corresponding with PD code (more granular than Offense Description)': FRAUD,UNCLASSIFIED-FELONY (Count: 157)
# Most common value in 'Indicator of whether crime was successfully completed or attempted, but failed or was interrupted prematurely': COMPLETED (Count: 977)
# Most common value in 'Level of offense: felony, misdemeanor, violation': FELONY (Count: 617)
# Most common value in 'The name of the borough in which the incident occurred': BROOKLYN (Count: 318)
# Most common value in 'Specific location of occurrence in or around the premises; inside, opposite of, front of, rear of': INSIDE (Count: 769)
# Most common value in 'Specific description of premises; grocery store, residence, street, etc.': RESIDENCE - APT. HOUSE (Count: 382)
# Most common value in 'Description of the jurisdiction code': N.Y. POLICE DEPT (Count: 901)
# Most common value in 'Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.': 0 (Count: 901)
# Most common value in 'Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)': (null) (Count: 1000)
# Most common value in 'Name of NYCHA housing development of occurrence, if applicable': (null) (Count: 994)
# Most common value in 'Development Level Code': (null) (Count: 920)
# Most common value in 'X-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)': 1026480.0 (Count: 36)
# Most common value in 'Y-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)': 262584.0 (Count: 36)
# Most common value in 'Suspect?s Age Group': (null) (Count: 740)
# Most common value in 'Suspect?s Race Description': (null) (Count: 531)
# Most common value in 'Suspect?s Sex Description': (null) (Count: 592)
# Most common value in 'Transit district in which the offense occurred.': 20.0 (Count: 1)
# Most common value in 'Midblock Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)': 40.8873136344706 (Count: 36)
# Most common value in 'Midblock Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)': -73.8472717577564 (Count: 36)
# Most common value in 'Geospatial Location Point (latitude and Longitude combined)': (40.8873136344706, -73.8472717577564) (Count: 36)
# Most common value in 'The name of the patrol borough in which the incident occurred': PATROL BORO BRONX (Count: 241)
# Most common value in 'Transit station name': (null) (Count: 998)
# Most common value in 'Victim?s Age Group': 25-44 (Count: 366)
# Most common value in 'Victim?s Race Description': BLACK (Count: 316)
# Most common value in 'Victim?s Sex Description': F (Count: 549)

# %% [markdown]
#  I fail to drop the null value when I do the counting part
#
# ---

# %%
for column in df1.columns:
    value_counts = df1[column].value_counts()

    # Exclude null values from the count
    if None in value_counts.index:
        value_counts = value_counts.drop(index=None)

    if not value_counts.empty:
        least_common = value_counts.idxmin()
        least_common_count = value_counts.min()
        print(f"Least common value in '{column}': {least_common} (Count: {least_common_count})")
    else:
        print(f"No non-null values in '{column}'")

        # found the most successful crime because it is least reported
# Out:
# Least common value in 'Randomly generated persistent ID for each complaint': 10600119 (Count: 1)
# Least common value in 'Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)': 2005-04-19T00:00:00.000 (Count: 1)
# Least common value in 'Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)': 10:20:00 (Count: 1)
# Least common value in 'Ending date of occurrence for the reported event, if exact time of occurrence is unknown': 2001-04-01T00:00:00.000 (Count: 1)
# Least common value in 'Ending time of occurrence for the reported event, if exact time of occurrence is unknown': 13:13:00 (Count: 1)
# Least common value in 'The precinct in which the incident occurred': 10.0 (Count: 1)
# Least common value in 'Date event was reported to police': 2006-05-15T00:00:00.000 (Count: 1)
# Least common value in 'Three digit offense classification code': 348 (Count: 1)
# Least common value in 'Description of offense corresponding with key code': VEHICLE AND TRAFFIC LAWS (Count: 1)
# Least common value in 'Three digit internal classification code (more granular than Key Code)': 567.0 (Count: 1)
# Least common value in 'Level of offense: felony, misdemeanor, violation': VIOLATION (Count: 71)
# Least common value in 'The name of the borough in which the incident occurred': (null) (Count: 1)
# Least common value in 'Specific location of occurrence in or around the premises; inside, opposite of, front of, rear of': OUTSIDE (Count: 2)
# Least common value in 'Specific description of premises; grocery store, residence, street, etc.': STORAGE FACILITY (Count: 1)
# Least common value in 'Description of the jurisdiction code': DEPT OF CORRECTIONS (Count: 1)
# Least common value in 'Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.': 72 (Count: 1)
# Least common value in 'Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)': (null) (Count: 1000)
# Least common value in 'Suspect?s Race Description': AMERICAN INDIAN/ALASKAN NATIVE (Count: 1)
# Least common value in 'Suspect?s Sex Description': U (Count: 25)
# Least common value in 'Transit district in which the offense occurred.': 20.0 (Count: 1)
# Least common value in 'The name of the patrol borough in which the incident occurred': PATROL BORO STATEN ISLAND (Count: 36)
# Least common value in 'Transit station name': 121 STREET (Count: 1)
# Least common value in 'Victim?s Age Group': UNKNOWN (Count: 8)

# %%
combined_datetime = pd.to_datetime(df1.iloc[:, 2] + ' ' + df1.iloc[:, 3])

# Set up the figure and create a scatter plot
plt.figure(figsize=(10, 5))  # Adjust figure size if needed
plt.scatter(combined_datetime, range(len(combined_datetime)), color='b', marker='o')
plt.title("Date-Time Relationship")
plt.xlabel("Datetime")
plt.ylabel("Observation Index")
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname T identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
